# %% [markdown]
# <a href="https://colab.research.google.com/github/Jhow3D/Python---M-dulo-3---An-lise-dedados-/blob/main/Aula_3_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

# %%
empresas = ['Apple','Google','Amazon','Microsoft','Tencent',"McDonald's",'Visa','Facebook','Alibaba','Louis Vuitton']

# %%
bilhoes =[947.062,819.573,705.646,611.460,214.023,196.526,191.032,186.421,169.966,124.273]

# %%
plt.plot(empresas,bilhoes)

# %%
plt.plot(empresas,bilhoes)
plt.title('Empresas mais ricas do mundo')
# Out:
# Text(0.5, 1.0, 'Empresas mais ricas do mundo')

# %%
plt.plot(empresas,bilhoes)
plt.title("Empresas mais ricas do mundo")
plt.xlabel('Empresas')
plt.ylabel('Bilhões')
# Out:
# Text(0, 0.5, 'Bilhões')

# %%
plt.rcParams["figure.figsize"] = (15,8)
plt.plot(empresas,bilhoes)
plt.title("Empresas mais ricas do mundo")
plt.xlabel('Empresas')
plt.ylabel('Bilhões')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.plot(empresas,bilhoes)
plt.title("Empresas mais ricas do mundo",fontsize=25)
plt.xlabel('Empresas', fontsize =20)
plt.ylabel('Bilhões',fontsize=20)
plt.show()

# %%
plt.plot(empresas,bilhoes, color = 'green')
plt.title("Empresas mais ricas do mundo",fontsize=25)
plt.xlabel('Empresas', fontsize =20)
plt.ylabel('Bilhões',fontsize=20)
plt.legend(['Bilhões de dólares'], loc = 'right', fontsize=15)
plt.show()

# %%
plt.plot(empresas,bilhoes, color = 'green', lw=10)
plt.xlabel("Empresas", fontsize=20)
plt.ylabel("Bilhões", fontsize=20)
plt.legend(['Bilhões de dólares'], loc = 'right', fontsize=15)
plt.show()

# %%
plt.plot(empresas,bilhoes, color = 'green', marker = 'o')
plt.title("Empresas mais ricas do mundo",fontsize=25)
plt.xlabel('Empresas', fontsize =20)
plt.ylabel('Bilhões',fontsize=20)
plt.legend(['Bilhões de dólares'], loc = 'right', fontsize=15)
plt.show()

# %%
plt.plot(empresas,bilhoes, color = 'green', marker = 'o')
plt.title("Empresas mais ricas do mundo",fontsize=25)
plt.xlabel('Empresas', fontsize =20)
plt.ylabel('Bilhões',fontsize=20)
plt.legend(['Bilhões de dólares'], loc = 'right', fontsize=15)
plt.grid(True) # Adicionando linha de grade 
plt.show()

# %%
plt.bar(empresas,bilhoes, color = 'green')
plt.title("Empresas mais ricas do mundo",fontsize=25)
plt.xlabel('Empresas', fontsize =20)
plt.ylabel('Bilhões',fontsize=20)
plt.legend(['Bilhões de dólares'], loc = 'high right', fontsize=15)
plt.grid(True) # Adicionando linha de grade 
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: MatplotlibDeprecationWarning: Unrecognized location 'high right'. Falling back on 'best'; valid locations are
# 	best
# 	upper right
# 	upper left
# 	lower left
# 	lower right
# 	right
# 	center left
# 	center right
# 	lower center
# 	upper center
# 	center
# This will raise an exception in 3.3.
#   """

# %%
plt.bar(empresas,bilhoes, color = 'green')
# Out:
# <BarContainer object of 10 artists>

# %%
cores = ['red','yellow','green','blue','purple','orange','magenta','white','black','brown']

# %%
plt.bar(empresas, bilhoes, color = cores, edgecolor='black')
plt.title("Empresas mais ricas do mundo")
plt.ylabel("Bilhões de dólares", fontsize=20)
plt.xlabel("Empresas", fontsize=20)
plt.grid(True)

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('bmh')
plt.bar(empresas, bilhoes, color = cores, edgecolor='black')
plt.title("Empresas mais ricas do mundo")
plt.ylabel("Bilhões de dólares", fontsize=20)
plt.xlabel("Empresas", fontsize=20)
plt.grid(True)

# %%
plt.style.use('bmh')
plt.barh(empresas, bilhoes, color = cores, edgecolor='black')
plt.title("Empresas mais ricas do mundo")
plt.ylabel("Bilhões de dólares", fontsize=20)
plt.xlabel("Empresas", fontsize=20)
plt.grid(True)

# %%
plt.style.use('bmh')
plt.scatter(empresas, bilhoes, color = cores, edgecolor='black')
plt.title("Empresas mais ricas do mundo")
plt.ylabel("Bilhões de dólares", fontsize=20)
plt.xlabel("Empresas", fontsize=20)
plt.grid(True)
